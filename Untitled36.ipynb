# %% [markdown]
# <a href="https://colab.research.google.com/github/kuni10saito/AIprogramming/blob/master/Untitled36.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from denki1 import *

# %%
plt.pie(data)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f52395678d0>,
# ...
#  [Text(0.08961723484097127, 1.0963433546200105, ''),
#   Text(-0.896704782236175, -0.637118932001533, ''),
#   Text(0.48602072485273073, -0.9868048718027422, ''),
#   Text(1.063938274759265, -0.279348075887913, ''),
#   Text(1.0998745324519006, -0.01661363487359295, '')])

# %%
plt.pie(data,labels=label)
pass

# %%
from syussei import *

# %%
plt.bar(np.arange(1,12),data2,tick_label=label, align="center")
pass
